# %%
### Prerequisities packages

import os ## to work with files
import pandas as pd ## dataframe tables
import numpy as np ## math
import plotly.plotly as py ## plots ["plotly" has to be installed, ideally with pip: https://plot.ly/python/getting-started/]
import plotly.graph_objs as go
import nltk ## natural language processing; for some functions, you have firstly download the data by nltk.download() function
import nltk.corpus  
from nltk.text import Text ## to transform text into a right format

# %%
### uploading the data from the same folder

GNT_df = pd.read_csv("../data_input/Nestle1904.csv", delim_whitespace=True, index_col=False, skiprows=1, names=("book", "ch_v", "func_morph", "pos1", "pos2", "strong", "lemma", "normalized"))
GNT_df
# Out:
#         book   ch_v   func_morph       pos1       pos2     strong     lemma  \
# 0       Matt    1:1       Βίβλος      N-NSF      N-NSF        976    βίβλος
# 1       Matt    1:1     γενέσεως      N-GSF      N-GSF       1078   γένεσις
# 2       Matt    1:1        Ἰησοῦ      N-GSM      N-GSM       2424    Ἰησοῦς
# 3       Matt    1:1      Χριστοῦ      N-GSM      N-GSM       5547   Χριστός
# 4       Matt    1:1         υἱοῦ      N-GSM      N-GSM       5207      υἱός
# 5       Matt    1:1       Δαυεὶδ      N-PRI      N-PRI       1138     Δαυίδ
# 6       Matt    1:1         υἱοῦ      N-GSM      N-GSM       5207      υἱός
# 7       Matt    1:1      Ἀβραάμ.      N-PRI      N-PRI         11    Ἀβραάμ
# 8       Matt    1:2       Ἀβραὰμ      N-PRI      N-PRI         11    Ἀβραάμ
# 9       Matt    1:2    ἐγέννησεν   V-AAI-3S   V-AAI-3S  1080&5656    γεννάω
# 10      Matt    1:2          τὸν      T-ASM      T-ASM       3588         ὁ
# 11      Matt    1:2       Ἰσαάκ,      N-PRI      N-PRI       2464     Ἰσαάκ
# 12      Matt    1:2        Ἰσαὰκ      N-PRI      N-PRI       2464     Ἰσαάκ
# 13      Matt    1:2           δὲ       CONJ       CONJ       1161        δέ
# 14      Matt    1:2    ἐγέννησεν   V-AAI-3S   V-AAI-3S  1080&5656    γεννάω
# 15      Matt    1:2          τὸν      T-ASM      T-ASM       3588         ὁ
# 16      Matt    1:2       Ἰακώβ,      N-PRI      N-PRI       2384     Ἰακώβ
# 17      Matt    1:2        Ἰακὼβ      N-PRI      N-PRI       2384     Ἰακώβ
# 18      Matt    1:2           δὲ       CONJ       CONJ       1161        δέ
# 19      Matt    1:2    ἐγέννησεν   V-AAI-3S   V-AAI-3S  1080&5656    γεννάω
# 20      Matt    1:2          τὸν      T-ASM      T-ASM       3588         ὁ
# 21      Matt    1:2       Ἰούδαν      N-ASM      N-ASM       2455    Ἰούδας
# 22      Matt    1:2          καὶ       CONJ       CONJ       2532       καί
# 23      Matt    1:2         τοὺς      T-APM      T-APM       3588         ὁ
# 24      Matt    1:2     ἀδελφοὺς      N-APM      N-APM         80   ἀδελφός
# 25      Matt    1:2       αὐτοῦ,      P-GSM      P-GSM        846     αὐτός
# 26      Matt    1:3       Ἰούδας      N-NSM      N-NSM       2455    Ἰούδας
# 27      Matt    1:3           δὲ       CONJ       CONJ       1161        δέ
# 28      Matt    1:3    ἐγέννησεν   V-AAI-3S   V-AAI-3S  1080&5656    γεννάω
# 29      Matt    1:3          τὸν      T-ASM      T-ASM       3588         ὁ
# ...      ...    ...          ...        ...        ...        ...       ...
# 137749   Rev  22:19          καὶ       CONJ       CONJ       2532       καί
# 137750   Rev  22:19           ἐκ       PREP       PREP       1537        ἐκ
# 137751   Rev  22:19          τῆς      T-GSF      T-GSF       3588         ὁ
# 137752   Rev  22:19       πόλεως      N-GSF      N-GSF       4172     πόλις
# 137753   Rev  22:19          τῆς      T-GSF      T-GSF       3588         ὁ
# 137754   Rev  22:19       ἁγίας,      A-GSF      A-GSF         40     ἅγιος
# 137755   Rev  22:19          τῶν      T-GPN      T-GPN       3588         ὁ
# 137756   Rev  22:19  γεγραμμένων  V-RPP-GPN  V-RPP-GPN  1125&5772     γράφω
# 137757   Rev  22:19           ἐν       PREP       PREP       1722        ἐν
# 137758   Rev  22:19           τῷ      T-DSN      T-DSN       3588         ὁ
# 137759   Rev  22:19       βιβλίῳ      N-DSN      N-DSN        975   βιβλίον
# 137760   Rev  22:19       τούτῳ.      D-DSN      D-DSN       3778     οὗτος
# 137761   Rev  22:20        Λέγει   V-PAI-3S   V-PAI-3S  3004&5719      λέγω
# 137762   Rev  22:20            ὁ      T-NSM      T-NSM       3588         ὁ
# 137763   Rev  22:20     μαρτυρῶν  V-PAP-NSM  V-PAP-NSM  3140&5723  μαρτυρέω
# 137764   Rev  22:20        ταῦτα      D-APN      D-APN       3778     οὗτος
# 137765   Rev  22:20         Ναί,        PRT        PRT       3483       ναί
# 137766   Rev  22:20      ἔρχομαι   V-PNI-1S   V-PNI-1S  2064&5736   ἔρχομαι
# 137767   Rev  22:20        ταχύ.        ADV        ADV       5035     ταχύς
# 137768   Rev  22:20        Ἀμήν,        HEB        HEB        281      ἀμήν
# 137769   Rev  22:20        ἔρχου   V-PNM-2S   V-PNM-2S  2064&5737   ἔρχομαι
# 137770   Rev  22:20        Κύριε      N-VSM      N-VSM       2962    κύριος
# 137771   Rev  22:20       Ἰησοῦ.      N-VSM      N-VSM       2424    Ἰησοῦς
# 137772   Rev  22:21            Ἡ      T-NSF      T-NSF       3588         ὁ
# 137773   Rev  22:21        χάρις      N-NSF      N-NSF       5485     χάρις
# 137774   Rev  22:21          τοῦ      T-GSM      T-GSM       3588         ὁ
# 137775   Rev  22:21       Κυρίου      N-GSM      N-GSM       2962    κύριος
# 137776   Rev  22:21        Ἰησοῦ      N-GSM      N-GSM       2424    Ἰησοῦς
# 137777   Rev  22:21         μετὰ       PREP       PREP       3326      μετά
# 137778   Rev  22:21      πάντων.      A-GPM      A-GPM       3956       πᾶς
#
#          normalized
# 0            Βίβλος
# 1          γενέσεως
# 2             Ἰησοῦ
# 3           Χριστοῦ
# 4              υἱοῦ
# 5            Δαυείδ
# 6              υἱοῦ
# 7            Ἀβραάμ
# 8            Ἀβραάμ
# 9         ἐγέννησεν
# 10              τόν
# 11            Ἰσαάκ
# 12            Ἰσαάκ
# 13               δέ
# 14        ἐγέννησεν
# 15              τόν
# 16            Ἰακώβ
# 17            Ἰακώβ
# 18               δέ
# 19        ἐγέννησεν
# 20              τόν
# 21           Ἰούδαν
# 22              καί
# 23             τούς
# 24         ἀδελφούς
# 25            αὐτοῦ
# 26           Ἰούδας
# 27               δέ
# 28        ἐγέννησεν
# 29              τόν
# ...             ...
# 137749          καί
# 137750           ἐκ
# 137751          τῆς
# 137752       πόλεως
# 137753          τῆς
# 137754        ἁγίας
# 137755          τῶν
# 137756  γεγραμμένων
# 137757           ἐν
# 137758           τῷ
# 137759       βιβλίῳ
# 137760        τούτῳ
# 137761        Λέγει
# 137762            ὁ
# 137763     μαρτυρῶν
# 137764        ταῦτα
# 137765          Ναί
# 137766      ἔρχομαι
# 137767         ταχύ
# 137768         Ἀμήν
# 137769        ἔρχου
# 137770        Κύριε
# 137771        Ἰησοῦ
# 137772            Ἡ
# 137773        χάρις
# 137774          τοῦ
# 137775       Κυρίου
# 137776        Ἰησοῦ
# 137777         μετά
# 137778       πάντων
#
# [137779 rows x 8 columns]

# %%
### A short demonstration of the data structure on Matt 1:18

pd.concat([GNT_df[283:301]["func_morph"], GNT_df[275:301]["lemma"], GNT_df[275:301]["pos1"]], axis=1)
# Out:
#         func_morph       lemma       pos1
# 275            NaN           ὁ      T-GSM
# 276            NaN          δέ       CONJ
# 277            NaN      Ἰησοῦς      N-GSM
# 278            NaN     Χριστός      N-GSM
# 279            NaN           ὁ      T-NSF
# 280            NaN     γένεσις      N-NSF
# 281            NaN        οὕτω        ADV
# 282            NaN        εἰμί   V-IAI-3S
# 283  μνηστευθείσης    μνηστεύω  V-APP-GSF
# 284            τῆς           ὁ      T-GSF
# 285         μητρὸς       μήτηρ      N-GSF
# 286          αὐτοῦ       αὐτός      P-GSM
# 287         Μαρίας       Μαρία      N-GSF
# 288             τῷ           ὁ      T-DSM
# 289         Ἰωσήφ,       Ἰωσήφ      N-PRI
# 290           πρὶν        πρίν        ADV
# 291              ἢ           ἤ        PRT
# 292      συνελθεῖν  συνέρχομαι     V-2AAN
# 293         αὐτοὺς       αὐτός      P-APM
# 294         εὑρέθη     εὑρίσκω   V-API-3S
# 295             ἐν          ἐν       PREP
# 296         γαστρὶ      γαστήρ      N-DSF
# 297         ἔχουσα         ἔχω  V-PAP-NSF
# 298             ἐκ          ἐκ       PREP
# 299      Πνεύματος      πνεῦμα      N-GSN
# 300         Ἁγίου.       ἅγιος      A-GSN

# %%
## one verse as a normal text

" ".join(GNT_df[275:317]["func_morph"].tolist())

### the original: Τοῦ δὲ Ἰησοῦ Χριστοῦ ἡ γένεσις οὕτως ἦν. μνηστευθείσης τῆς μητρὸς αὐτοῦ Μαρίας τῷ Ἰωσήφ, πρὶν ἢ συνελθεῖν αὐτοὺς εὑρέθη ἐν γαστρὶ ἔχουσα ἐκ Πνεύματος Ἁγίου. Ἰωσὴφ δὲ ὁ ἀνὴρ αὐτῆς, δίκαιος ὢν καὶ μὴ θέλων αὐτὴν δειγματίσαι, ἐβουλήθη λάθρᾳ ἀπολῦσαι αὐτήν.'

### the reducedt text has the following form in this case:
### ἰησοῦς χριστός γένεσις οὕτω εἰμί μνηστεύω μήτηρ μαρία ἰωσήφ πρίν συνέρχομαι εὑρίσκω ἐν γαστήρ ἔχω ἐκ πνεῦμα ἅγιος ἰωσήφ ἀνήρ δίκαιος εἰμί μή θέλω δειγματίζω βούλομαι λάθρᾳ ἀπολύω
# Out:
# 'Τοῦ δὲ Ἰησοῦ Χριστοῦ ἡ γένεσις οὕτως ἦν. μνηστευθείσης τῆς μητρὸς αὐτοῦ Μαρίας τῷ Ἰωσήφ, πρὶν ἢ συνελθεῖν αὐτοὺς εὑρέθη ἐν γαστρὶ ἔχουσα ἐκ Πνεύματος Ἁγίου. Ἰωσὴφ δὲ ὁ ἀνὴρ αὐτῆς, δίκαιος ὢν καὶ μὴ θέλων αὐτὴν δειγματίσαι, ἐβουλήθη λάθρᾳ ἀπολῦσαι αὐτήν.'

# %%
# A list of unique word forms

# open question: how to approach pronouns - the of "we" is here "ego"
#  GNT_df[GNT_df.pos1.str.startswith("P-1")]

GNT_df.pos1.unique().tolist()
# Out:
# ['N-NSF',
#  'N-GSF',
#  'N-GSM',
#  'N-PRI',
#  'V-AAI-3S',
#  'T-ASM',
#  'CONJ',
#  'N-ASM',
#  'T-APM',
#  'N-APM',
#  'P-GSM',
#  'N-NSM',
#  'PREP',
#  'T-GSF',
#  'T-GSM',
#  'T-ASF',
#  'N-ASF',
#  'R-GSF',
#  'V-API-3S',
#  'T-NSM',
#  'V-PPP-NSM',
#  'A-NPF',
#  'T-NPF',
#  'N-NPF',
#  'ADV',
#  'T-NSF',
#  'V-IAI-3S',
#  'V-APP-GSF',
#  'T-DSM',
#  'PRT',
#  'V-2AAN',
#  'P-APM',
#  'N-DSF',
#  'V-PAP-NSF',
#  'N-GSN',
#  'A-GSN',
#  'P-GSF',
#  'A-NSM',
#  'V-PAP-NSM',
#  'PRT-N',
#  'P-ASF',
#  'V-AAN',
#  'V-AOI-3S',
#  'D-APN',
#  'V-AOP-GSM',
#  'V-2AMM-2S',
#  'N-OI',
#  'V-2API-3S',
#  'P-DSM',
#  'V-AOS-2S',
#  'P-2GS',
#  'T-NSN',
#  'P-DSF',
#  'V-APP-NSN',
#  'V-PAI-3S',
#  'V-FDI-3S',
#  'V-FAI-2S',
#  'T-ASN',
#  'N-ASN',
#  'P-NSM',
#  'V-FAI-3S',
#  'T-GPF',
#  'N-GPF',
#  'P-GPM',
#  'D-NSN',
#  'A-NSN',
#  'V-2RAI-3S',
#  'V-APS-3S',
#  'V-PAP-GSM',
#  'V-FAI-3P',
#  'R-NSN',
#  'V-PPP-NSN',
#  'P-1GP',
#  'V-APP-NSM',
#  'V-2AAI-3S',
#  'R-GSM',
#  'V-APP-GSM',
#  'N-DPF',
#  'N-NPM',
#  'V-2ADI-3P',
#  'N-APN',
#  'V-PAP-NPM',
#  'ADV-I',
#  'T-GPM',
#  'A-GPM',
#  'V-2AAI-1P',
#  'T-DSF',
#  'V-AAP-NSM',
#  'A-NSF',
#  'V-2AAP-NSM',
#  'A-APM',
#  'V-INI-3S',
#  'V-PPI-3S',
#  'T-NPM',
#  'V-2AAI-3P',
#  'V-RPI-3S',
#  'P-2NS',
#  'N-VSF',
#  'ADV-N',
#  'A-NSF-S',
#  'V-PAI-2S',
#  'T-DPM',
#  'N-DPM',
#  'V-PNP-NSM',
#  'R-NSM',
#  'P-1GS',
#  'V-PEP-GSM',
#  'V-AOP-NPM',
#  'V-AAM-2P',
#  'T-GSN',
#  'V-2AAS-2P',
#  'P-1DS',
#  'P-1NS-K',
#  'V-AAS-1S',
#  'V-AAP-NPM',
#  'V-AOI-3P',
#  'R-ASM',
#  'N-NSN',
#  'V-2AAP-NPM',
#  'V-2AOI-3P',
#  'A-ASF',
#  'P-GSN',
#  'V-AAI-3P',
#  'V-APP-NPM',
#  'A-GSF',
#  'V-AAP-GPM',
#  'V-PEI-3S',
#  'V-2AAM-2S',
#  'V-PAM-2S',
#  'V-2AAS-1S',
#  'P-2DS',
#  'V-PAN',
#  'P-ASN',
#  'V-AAI-1S',
#  'N-GPM',
#  'A-DPN',
#  'T-DPN',
#  'N-DPN',
#  'A-GSM',
#  'T-APN',
#  'V-APN',
#  'V-PAI-3P',
#  'V-AAP-GSM',
#  'V-PNM-2S',
#  'V-RAI-3P',
#  'V-PPP-ASF',
#  'V-FPI-3S',
#  'T-DPF',
#  'D-DPF',
#  'V-PNI-3S',
#  'A-DSF',
#  'V-PAM-2P',
#  'V-RAI-3S',
#  'D-NSM',
#  'A-APF',
#  'T-APF',
#  'N-APF',
#  'P-ASM',
#  'V-IPI-3P',
#  'N-DSM',
#  'V-PMP-NPM',
#  'V-PNP-APM',
#  'P-DPM',
#  'N-VPN',
#  'I-NSM',
#  'P-2DP',
#  'V-PAP-GSF',
#  'A-ASM',
#  'V-AAS-2P',
#  'F-2DPM',
#  'V-PAI-1P',
#  'V-PAI-1S',
#  'D-GPM',
#  'T-GPN',
#  'N-GPN',
#  'V-PAP-NSN',
#  'P-1NS',
#  'P-2AP',
#  'N-DSN',
#  'A-NSM-C',
#  'A-DSN',
#  'V-FAI-3S-ATT',
#  'V-PNI-2S',
#  'P-1AS',
#  'V-AOP-NSM',
#  'P-1DP',
#  'V-API-3P',
#  'V-PAP-ASN',
#  'V-PNP-ASN',
#  'R-DSM',
#  'A-NUI',
#  'COND',
#  'D-NPM',
#  'V-2ADS-3P',
#  'A-DSM',
#  'V-PNP-DSN',
#  'F-2ASM',
#  'V-FNI-3S',
#  'P-2AS',
#  'V-AAS-2S',
#  'A-ASN',
#  'P-GPF',
#  'A-APN',
#  'V-FAI-1S',
#  'N-VSM',
#  'V-IAI-3P',
#  'V-PNP-DPM',
#  'V-AMI-3S',
#  'V-PPP-ASM',
#  'V-PAP-APM',
#  'T-DSN',
#  'A-DPF',
#  'V-PPP-APM',
#  'A-NPM',
#  'P-NPM',
#  'V-FPI-3P',
#  'V-FDI-3P',
#  'V-RPP-NPM',
#  'V-PAI-2P',
#  'V-AAS-3P',
#  'V-2AAS-3P',
#  'P-2GP',
#  'V-PEP-NPM',
#  'V-PNM-2P',
#  'P-2NP',
#  'I-DSN',
#  'A-ASN-N',
#  'V-PPN',
#  'V-2APN',
#  'V-PNP-NSF',
#  'CONJ-N',
#  'A-DPM',
#  'V-AAM-3S',
#  'V-2AAI-1S',
#  'HEB',
#  'V-2AAS-3S',
#  'N-LI',
#  'A-NPN',
#  'V-2ADS-3S',
#  'V-AAS-3S',
#  'D-GPF',
#  'A-GPF-S',
#  'A-NSM-S',
#  'A-ASN-C',
#  'V-AAI-2P',
#  'ARAM',
#  'A-VSM',
#  'V-PAS-2S',
#  'ADV-K',
#  'V-APS-2S',
#  'X-ASN',
#  'ADV-S',
#  'V-2APM-2S',
#  'R-GSN-ATT',
#  'V-FPI-2S',
#  'V-2AAS-2S',
#  'A-ASM-S',
#  'V-2AMS-3S',
#  'V-AAM-2S',
#  'V-2AAM-3S',
#  'V-RPP-ASF',
#  'V-PAM-3S',
#  'V-PAP-DSM',
#  'V-PAP-ASM',
#  'V-AMN',
#  'V-2APS-2S',
#  'V-PAP-GPM',
#  'V-2ADS-2P',
#  'I-ASM',
#  'PRT-I',
#  'V-ADS-2P',
#  'I-ASN',
#  'V-FDI-2P',
#  'V-APS-3P',
#  'V-PAS-3S',
#  'V-PNS-2P',
#  'V-RAP-NPM',
#  'V-PNN',
#  'V-2APS-3P',
#  'V-PNS-2S',
#  'V-ADM-2S',
#  'V-PNP-NPM',
#  'V-APS-2P',
#  'R-GPN',
#  'V-APM-3S',
#  'V-AOM-3S',
#  'P-1NP',
#  'V-AAI-1P',
#  'P-1AP',
#  'V-PAS-2P',
#  'V-AMM-2S',
#  'Q-NSN',
#  'A-NSM-N',
#  'V-PNI-2P',
#  'D-ASN',
#  'V-AMS-2P',
#  'A-NSN-C',
#  'P-APN',
#  'P-GPN',
#  'V-2AAM-2P',
#  'V-2AMI-3S',
#  'D-GPN',
#  'A-VPM',
#  'V-2AAS-1P',
#  'V-2AMS-1P',
#  'T-NPN',
#  'N-NPN',
#  'A-GPN',
#  'D-NPN',
#  'F-3GSF',
#  'R-DSN',
#  'V-FPI-2P',
#  'S-2SDSM',
#  'V-2APP-NPM',
#  'V-FAI-2P',
#  'V-2FPI-3S',
#  'V-RAI-2P',
#  'Q-DSN',
#  'V-PAP-DPM',
#  'K-APN',
#  'V-PAS-3P',
#  'V-RPP-NSF',
#  'R-NPM',
#  'V-PNI-3P',
#  'D-DSF',
#  'S-2SDSN',
#  'D-APM',
#  'V-LPI-3S',
#  'V-2ADI-3S',
#  'V-2AAP-GSM',
#  'V-ADI-3S',
#  'V-APM-2S',
#  'A-DSM-N',
#  'R-ASN',
#  'F-1ASM',
#  'D-DSM',
#  'V-AOM-2S',
#  'D-ASF',
#  'V-AAI-2S',
#  'V-PAP-ASF',
#  'V-2ADP-GSF',
#  'F-3GPM',
#  'V-2AAP-DSM',
#  'V-PMI-1P',
#  'I-NSN',
#  'X-ASM',
#  'D-GSF',
#  'V-2AAI-2S',
#  'V-PPP-NSF',
#  'V-PNP-GPM',
#  'V-RPP-ASM',
#  'N-VSN',
#  'V-PPI-3P',
#  'X-NPM',
#  'F-3DPM',
#  'V-RAP-NSM',
#  'V-RAS-2P',
#  'V-2AAP-ASM',
#  'V-PNP-ASM',
#  'V-PNP-GSM',
#  'V-INI-3P',
#  'K-ASM',
#  'V-2AAP-NSF',
#  'F-3DSF',
#  'V-AMS-1S',
#  'V-FPI-1S',
#  'V-2APP-NSM',
#  'D-NSF',
#  'V-PNI-1S',
#  'V-APP-GSN',
#  'V-PAP-NPN',
#  'V-AOM-2P',
#  'V-ADP-NSM',
#  'V-2RAP-APN',
#  'V-2AAI-2P',
#  'R-ASF',
#  'V-ADM-2P',
#  'V-2APM-3S',
#  'V-ADS-3S',
#  'V-PPP-NPM',
#  'V-APS2P',
#  'A-NSN-N',
#  'V-RPP-NSN',
#  'V-PEM-2P@@V-PNM-2P',
#  'V-RPP-NPF',
#  'V-FDI-1S',
#  'V-AAP-ASM',
#  'R-APN',
#  'V-ADN',
#  'V-PNP-DPN',
#  'R-NPN',
#  'V-ADI-2P',
#  'V-AMI-2P',
#  'R-DPF',
#  'A-NPF-S',
#  'INJ',
#  'V-2ADP-NPF',
#  'V-FDI-2S',
#  'V-PMI-1S',
#  'X-NSM',
#  'V-PNS-3S',
#  'V-AMI-3P',
#  'V-LAI-2P',
#  'V-PPP-ASN',
#  'V-FAI-3P-ATT',
#  'V-IMI-3P',
#  'V-APP-NSF',
#  'F-3ASM',
#  'I-DSM',
#  'V-ADI-3P',
#  'V-FMI-3P',
#  'V-2AAP-NSN',
#  'F-3GSN',
#  'A-APN-C',
#  'V-2AAP-NPN',
#  'A-NPN-S',
#  'D-GSM',
#  'A-GPN-S',
#  'V-LAI-3P',
#  'I-NSF',
#  'I-NPM',
#  'V-LAI-3S',
#  'D-DPM',
#  'V-2RPP-ASN',
#  'F-3DSM',
#  'V-AAP-DSM',
#  'V-AAS-1P',
#  'P-DPN',
#  'V-RPP-APN',
#  'V-RPP-DSM',
#  'D-ASM',
#  'V-APP-DSF',
#  'V-2AAP-DSF',
#  'D-APF',
#  'V-2ADP-DPN',
#  'V-AMS-3S',
#  'V-AMP-NSM',
#  'V-2AAP-GPM',
#  'V-AMS-3P',
#  'K-NPM',
#  'A-GPM-C',
#  'V-PMI-3P',
#  'N-VPM',
#  'V-PNP-NSN',
#  'V-RAI-2S',
#  'V-FNI-3P',
#  'V-PNP-NPN',
#  'D-NPN-K',
#  'V-2API-1S',
#  'V-PAP-GPN',
#  'Q-APM',
#  'Q-APF',
#  'V-2AMP-NSM',
#  'A-NSM-ATT',
#  'V-ADM-3S',
#  'V-RAP-GPM',
#  'V-ADS-3P',
#  'V-APM-2P',
#  'A-ASM-N',
#  'V-AOI-3P-ATT',
#  'A-VSF',
#  'P-DSN',
#  'V-AOI-1P-ATT',
#  'D-DSN',
#  'V-PPP-GPM',
#  'I-GPM',
#  'V-2APS-2P',
#  'X-DSM',
#  'V-RPP-DPN',
#  'V-RPP-NPN',
#  'R-GSN',
#  'S-1SASN',
#  'V-AMP-GSM',
#  'V-2ADP-APN',
#  'D-GSN',
#  'R-DPM',
#  'F-3APM',
#  'I-APF',
#  'V-PAP-APN',
#  'S-1SGSN',
#  'A-NPM-S',
#  'V-RAP-APM',
#  'A-GPM-S',
#  'V-AAP-DPM',
#  'S-2SASN',
#  'A-DSM-S',
#  'S-1SDPN',
#  'V-PMI-2P',
#  'V-PNI-1P',
#  'S-1SNSN',
#  'V-2ADN',
#  'ADV-C',
#  'V-RPP-NSM',
#  'A-DPN-S',
#  'V-AMI-2S',
#  'COND-K',
#  'A-NPM-C',
#  'I-DSF',
#  'V-RAI-1P',
#  'A-DSN-S',
#  'V-AOI-2P',
#  'A-APM-C',
#  'V-2FPI-3P',
#  'V-PAP-DSN',
#  'V-RPP-APM',
#  'V-RPP-DPM',
#  'V-RAI-1S',
#  'K-APM',
#  'R-APM',
#  'V-RMP-ASM',
#  'A-GSM-N',
#  'I-GSM',
#  'V-PPI-2P',
#  'V-APP-ASN',
#  'V-RPP-GPM',
#  'V-AON',
#  'V-PAI-3P-ATT',
#  'N-ASF-S',
#  'N-APF-S',
#  'A-ASM-C',
#  'V-PNP-DSM',
#  'D-APN-K',
#  'V-PEI-3P',
#  'V-IMI-1P',
#  'S-2SGSF',
#  'V-PPM-2P',
#  'C-APM',
#  'V-2RAP-ASN',
#  'V-PAM-3P',
#  'V-PAP-DPF',
#  'R-NSF',
#  'D-NPF',
#  'V-PAP-NPF',
#  'V-2LAI-3S',
#  'R-DSF',
#  'V-PAP-DPN',
#  'R-NPF',
#  'V-2AAP-NPF',
#  'F-3GPF',
#  'F-2DPF',
#  'V-PNP-GPF',
#  'V-IAI-2S',
#  'V-2RAP-NSM',
#  'V-2LAI-2S',
#  'V-AMI-1S',
#  'C-GPM',
#  'V-IMI-1S',
#  'V-FOI-3P',
#  'K-ASN',
#  'V-RPP-ASN',
#  'V-FOI-3S',
#  'V-PPP-GSM',
#  'V-2ADP-GSM',
#  'F-2GPM',
#  'A-DSF-S',
#  'V-PAS-1S',
#  'V-ADS-1S',
#  'V-PEM-2P',
#  'V-PAS-1P',
#  'V-INI-1S',
#  'A-GPF',
#  'V-RAP-GSM-ATT',
#  'A-DPM-C',
#  'V-RPP-GSM',
#  'Q-APN',
#  'V-FAI-1P',
#  'V-FAP-NSM',
#  'V-PNP-APN',
#  'V-PNP-NPF',
#  'V-API-1P',
#  'V-PPI-1S',
#  'A-NSF-C',
#  'A-GSF-S',
#  'V-PAP-DSF',
#  'V-AOP-NPF',
#  'P-DPF',
#  'V-ADI-1S',
#  'V-RMP-NSM',
#  'V-AAP-NSN',
#  'V-2LAI-3P',
#  'V-PPP-APF',
#  'V-PMN',
#  'S-2SNPM',
#  'F-3ASF',
#  'V-PPP-NPN',
#  'V-2RPP-ASM',
#  'X-NSN',
#  'V-PPS-3S',
#  'V-2APS-3S',
#  'V-INI-3P-ATT',
#  'V-RPM-2S',
#  'V-RPN',
#  'A-GSM-S',
#  'V-2RAP-NSN',
#  'V-RAP-ASM',
#  'S-2SAPM',
#  'V-AAP-NSF',
#  'V-2AAP-ASF',
#  'V-IMI-3S',
#  'V-AAP-ASF',
#  'V-AOP-NSF',
#  'V-RAP-NSF',
#  'V-2ADP-GSN',
#  'A-ASF-N',
#  'V-INI-3S-ATT',
#  'N-DPM-S',
#  'A-DPM-S',
#  'V-2AAP-GSF',
#  'V-ADP-GSF',
#  'V-2ADP-NSM',
#  'V-AMM-2P',
#  'X-APM',
#  'V-AOI-3S-ATT',
#  'V-2API-3P',
#  'Q-GPF',
#  'V-AOS-3S',
#  'S-1SAPM',
#  'V-2RAP-ASF',
#  'V-AMP-NPM',
#  'V-IEI-3S',
#  'Q-NSM',
#  'A-DSN-N',
#  'V-FMI-3S',
#  'V-INI-2P',
#  'V-IAI-1P',
#  'C-DPM',
#  'P-NSF',
#  'V-2AAO-3S',
#  'V-IPI-3S',
#  'V-ADI-2S',
#  'X-GSM',
#  'D-ASM-K',
#  'A-ASN-S',
#  'V-PAP-GSN',
#  'F-2APM',
#  'V-2FPI-2P',
#  'V-ANI-3P',
#  'V-PMP-NSM',
#  'V-AOS-3P',
#  'V-LAI-3S-ATT',
#  'V-PMP-ASM',
#  'V-RAP-DPM',
#  'F-3APF',
#  'V-AAP-NPF',
#  'P-APF',
#  'V-2ADP-DPM',
#  'D-NPM-K',
#  'V-ADP-DPM',
#  'V-RPP-GPN',
#  'V-2ADP-NPM',
#  'P-1DS-K',
#  'V-RAP-DSM',
#  'A-VSM-S',
#  'R-GPM',
#  'V-API-2S',
#  'V-2FOI-3P',
#  'V-RAI-3S-ATT',
#  'V-PAO-3S',
#  'V-PPP-DSF',
#  'V-2ADO-3S',
#  'V-2AMI-3P',
#  'V-APP-APM',
#  'R-DPN',
#  'V-PEN',
#  'F-3GSM',
#  'V-RPP-DSF',
#  'V-APP-GPN',
#  'V-2AAI-3P-ATT',
#  'V-RPP-ASN-ATT',
#  'V-PPP-DPN',
#  'V-IAI-2P',
#  'V-2LAI-2P',
#  'V-APP-GPF',
#  'V-RAP-APN',
#  'V-2AAP-APM',
#  'V-2AMN',
#  'V-2RAP-NPM',
#  'I-GSF',
#  'V-RPI-3P',
#  'V-2RAI-1S',
#  'V-AAO-3P',
#  'S-2PNSF',
#  'V-2AOM-2P',
#  'S-2SAPN',
#  'V-IAI-3S-ATT',
#  'V-2FDI-2S',
#  'V-PPM-2S',
#  'C-DPN',
#  'V-PMI-3S',
#  'X-NPF',
#  'V-2APP-NSN',
#  'V-2APP-NPF',
#  'V-PNS-3P',
#  'X-GPM',
#  'V-AOI-1S',
#  'V-2AMM-2P',
#  'V-PPP-APN',
#  'V-APP-ASM',
#  'V-IAI-1S',
#  'V-2RAN',
#  'X-ASF',
#  'X-NSF',
#  'V-PPI-2S',
#  'D-NSM-K',
#  'K-GPN',
#  'P-NSN',
#  'V-2AAP-GSN',
#  'V-2AMP-GSM',
#  'A-GPN-C',
#  'V-PMM-2P',
#  'V-2FAI-1S',
#  'A-APF-C',
#  'V-PMM-2S',
#  'V-2ADI-1S',
#  'V-2RAI-3P',
#  'V-FMI-2P',
#  'V-RPI-2S',
#  'V-RAN',
#  'V-FMI-2S',
#  'Q-NPM',
#  'A-ASF-S',
#  'V-APS-1P',
#  'V-APS-1S',
#  'S-1SNPN',
#  'S-2SNPN',
#  'V-2AON',
#  'Q-ASN',
#  'V-2ADI-2P',
#  'S-1PASN',
#  'D-DPN',
#  'V-AAM-3P',
#  'V-APP-APN',
#  'X-DSF',
#  'V-2RAP-APM',
#  'V-PMS-3S',
#  'V-2ADI-2S',
#  'V-PNP-ASF',
#  'V-AAP-APM',
#  'R-GPF',
#  'V-PMP-GSM',
#  'V-AOS-2P',
#  'V-PNM-3P',
#  'V-PNP-GPN',
#  'V-PMP-GPN',
#  'S-1SASF',
#  'V-PNM-3S',
#  'X-GSN',
#  'A-GSN-N',
#  'S-2SNSN',
#  'V-FDP-ASN',
#  'V-2ADP-APM',
#  'V-2AOI-3S',
#  'V-2ADP-ASF',
#  'N-VPF',
#  'F-2APF',
#  'V-APP-GPM',
#  'V-2ADP-ASN',
#  'V-RNP-NSM',
#  'V-2RAP-NPF',
#  'V-2ADP-GPF',
#  'V-PAP-GPF',
#  'V-RAP-GPN',
#  'I-APN',
#  'V-RAN-ATT',
#  'V-ADI-1P',
#  'F-2GSM',
#  'V-2LAI-1S',
#  'V-RNI-1S',
#  'V-RAI-1S-ATT',
#  'V-2RAP-ASM',
#  'V-2RAI-2S',
#  'V-RAI-1P-ATT',
#  'V-IDI-3P',
#  'S-1SNSF',
#  'V-PNP-GSN',
#  'V-PNS-1S',
#  'V-RAI-2S-ATT',
#  'V-2RAI-2P',
#  'S-2SASF',
#  'V-2RAI-1P-ATT',
#  'V-RAP-NPM-ATT',
#  'F-1GSM',
#  'A-ASF-C',
#  'P-NPN',
#  'V-2RAI-2P-ATT',
#  'V-RAI-2P-ATT',
#  'V-AAP-APN',
#  'V-API-2P',
#  'V-PMP-ASF',
#  'V-PNS-1P',
#  'V-FDI-1P',
#  'S-1SNSM',
#  'S-2PNSM',
#  'P-1AS-K',
#  'V-RPI-2P',
#  'S-2PDSM',
#  'S-1SDSM',
#  'S-1SASM',
#  'V-LMI-3P',
#  'I-NPN',
#  'S-1SAPN',
#  'S-1SGPN',
#  'V-2AMS-3P',
#  'V-AMS-2S',
#  'V-RAP-GSM',
#  'V-ADP-NPM',
#  'V-LAI-3P-ATT',
#  'I-APM',
#  'S-1SNPM',
#  'V-ADS-2S',
#  'V-PPM-3S',
#  'V-AOS-1S',
#  'V-RAP-NSM-ATT',
#  'S-1SAPF',
#  'V-2AOI-2P',
#  'S-1SDSF',
#  'S-2PASM',
#  'V-RAI-3P-ATT',
#  'V-2FOI-3S',
#  'F-2DSM',
#  'V-RPI-1S',
#  'S-2SNSM',
#  'V-2RAP-APM-ATT',
#  'I-ASF',
#  'V-2APP-NSF',
#  'V-RPP-GPF',
#  'V-PNP-GSF',
#  'V-FAN',
#  'V-ANP-NSM',
#  'V-PPP-GSN',
#  'V-2AAP-DPM',
#  'V-PPP-GSF',
#  'V-PEP-NPF',
#  'S-1PDPF',
#  'V-RPP-NSN-ATT',
#  'A-DPF-S',
#  'CONJ-P',
#  'V-RAP-DSN',
#  'A-VPM-C',
#  'V-PPI-1P',
#  'V-2AMP-NPM',
#  'V-AMS-1P',
#  'V-2RAP-DSN',
#  'V-AOP-GPM',
#  'V-PPP-GPN',
#  'V-RAP-GSF',
#  'S-2SDSF',
#  'V-2AMI-2S',
#  'V-2AMI-2P',
#  'V-PPP-DSM',
#  'V-FAI-1S-ATT',
#  'V-PMP-DSM',
#  'V-PNP-APF',
#  'V-RNI-3S',
#  'V-RAP-NSN',
#  'V-PNO-1S',
#  'V-PMP-APM',
#  'V-INI-2S',
#  'X-APF',
#  'V-2ADP-ASM',
#  'V-PMP-NPF',
#  'V-API-1S',
#  'V-FDN',
#  'V-AOI-2P-ATT',
#  'A-GSN-S',
#  'A-APM-S',
#  'V-RNP-DPF',
#  'V-RAP-ASF',
#  'V-AMP-APM',
#  'V-AMI-1P',
#  'V-RPM-2P',
#  'V-ADS-1P',
#  'V-2AAP-DPF',
#  'V-RPP-APF',
#  'V-2AAM-3P',
#  'X-APN',
#  'V-2AAO-3P',
#  'V-PMP-GPM',
#  'V-2AMI-1S',
#  'D-APM-K',
#  'V-2AAP-APF',
#  'V-AOP-NSN',
#  'I-GSN',
#  'V-FAP-APN',
#  'F-1DSM',
#  'V-INI-1P',
#  'V-2ADP-GPM',
#  'Q-NPF',
#  'V-RPP-VSM',
#  'V-PNI-2S-ATT',
#  'V-2AAP-ASN',
#  'F-1APM',
#  'N-ASM-S',
#  'A-NPF-C',
#  'V-PAO-3P',
#  'V-FMI-1S',
#  'V-RMI-2S',
#  'X-GPF',
#  'V-PNO-3S',
#  'S-1PGSF',
#  'V-AAP-ASN',
#  'V-ADO-1S',
#  'V-LDI-3S',
#  'V-2API-1P',
#  'V-AOP-DSM',
#  'V-PNO-3P',
#  'V-IPI-1P',
#  'A-NSF-N',
#  'S-2PGSF',
#  'V-2FMI-3S',
#  'X-GPN',
#  'V-PMP-ASN',
#  'V-PPP-DPM',
#  'V-PMP-DPM',
#  'S-1SDSN',
#  'V-2RAP-GPN',
#  'V-FPI-1P',
#  'V-2RAI-1P',
#  'V-APP-DSM',
#  'F-1DPM',
#  'V-RAP-NPN',
#  'K-NSN',
#  'V-AOI-1P',
#  'S-1SGSF',
#  'V-APM-3P',
#  'V-2FPI-2S',
#  'V-2API-2S',
#  'V-2AMS-1S',
#  'S-2PDSN',
#  'V-APP-ASF',
#  'V-PMM-3S',
#  'K-NPN',
#  'S-1PASF',
#  'V-AAO-3S',
#  'V-2RAI-3P-ATT',
#  'V-IPI-1S',
#  'V-PAP-APF',
#  'V-RPP-GSN',
#  'V-PEP-DPM',
#  'V-RAS-1P',
#  'V-AOI-1S-ATT',
#  'V-2ADM-3S',
#  'V-PPS-2P',
#  'V-ADP-ASM',
#  'V-PMS-1S',
#  'V-2ADS-1S',
#  'V-AMM-3S',
#  'V-IPI-2P',
#  'A-NPN-C',
#  'V-PPP-DSN',
#  'C-GPN',
#  'V-RAS-1S',
#  'V-PPS-3P',
#  'V-PPM-3P',
#  'S-2PASF',
#  'K-NSM',
#  'V-2FPI-1P',
#  'S-2PASN',
#  'V-PMP-GSF',
#  'V-ANI-3S',
#  'K-NPF',
#  'A-DSF-C',
#  'V-RPP-GSF',
#  'F-1GPM',
#  'V-RPP-DSN',
#  'V-2AMI-1P',
#  'V-RPI-1P',
#  'V-2APM-2P',
#  'V-2ADS-1P',
#  'Q-ASF',
#  'V-2AOI-1P',
#  'V-RNP-ASF',
#  'V-RMI-3S',
#  'X-DPM',
#  'V-2APP-ASM',
#  'V-PPS-1S',
#  'V-2APS-1P',
#  'V-PEI-2P',
#  'V-PMP-NSF',
#  'X-DSN',
#  'S-2PDSF',
#  'A-DSM-C',
#  'V-RAM-2P',
#  'V-2FOI-1S',
#  'V-2AOS-2P',
#  'V-2AOI-1S',
#  'V-PMP-NSN',
#  'V-POP-NPM',
#  'V-APO-3S',
#  'V-2FAI-3S',
#  'R-APF',
#  'I-GPN',
#  'V-PMS-2S',
#  'V-PNP-DPF',
#  'V-RAS-2S',
#  'V-2RAP-NSF',
#  'A-GSM-C',
#  'V-2ADM-2S',
#  'V-RNP-NPM',
#  'S-1PDPM',
#  ...]

# %%
## The text as a list of lemmata

GNT_lemmata = GNT_df["lemma"].tolist()

# %%
# selecting the relevant words in the dataframe

# this version does not include pronouns ("P-1", "P-2")
GNT_reduced = GNT_df[GNT_df["pos1"].str.startswith(("N-","V-","A-","ADV", "PRT-N", "PREP"))]


# Make a lowercase list from the sellected lemmata

GNT_working = GNT_reduced["lemma"].tolist()

# Make a a string
GNT_working = " ".join(GNT_working)
GNT_working = GNT_working.lower()
GNT_working
# Out:
# 'βίβλος γένεσις ἰησοῦς χριστός υἱός δαυίδ υἱός ἀβραάμ ἀβραάμ γεννάω ἰσαάκ ἰσαάκ γεννάω ἰακώβ ἰακώβ γεννάω ἰούδας ἀδελφός ἰούδας γεννάω φάρες ζάρα ἐκ θαμάρ φάρες γεννάω ἑσρώμ ἑσρώμ γεννάω ἀράμ ἀράμ γεννάω ἀμιναδάβ ἀμιναδάβ γεννάω ναασσών ναασσών γεννάω σαλμών σαλμών γεννάω βόες ἐκ ῥαχάβ βόες γεννάω ἰωβήδ ἐκ ῥούθ ἰωβήδ γεννάω ἰεσσαί ἰεσσαί γεννάω δαυίδ βασιλεύς δαυίδ γεννάω σολομών ἐκ οὐρίας σολομών γεννάω ῥοβοάμ ῥοβοάμ γεννάω ἀβιά ἀβιά γεννάω ἀσάφ ἀσάφ γεννάω ἰωσαφάτ ἰωσαφάτ γεννάω ἰωράμ ἰωράμ γεννάω ὀζίας ὀζίας γεννάω ἰωαθάμ ἰωαθάμ γεννάω ἀχάζ ἀχάζ γεννάω ἑζεκίας ἑζεκίας γεννάω μανασσῆ μανασσῆ γεννάω ἀμώς ἀμώς γεννάω ἰωσίας ἰωσίας γεννάω ἰεχονίας ἀδελφός ἐπί μετοικεσία βαβυλών μετά μετοικεσία βαβυ
#  '1Tim',
#  '2Tim',
#  'Titus',
#  'Phlm',
#  'Heb',
#  'Jas',
#  '1Pet',
#  '2Pet',
#  '1John',
#  '2John',
#  '3John',
#  'Jude',
#  'Rev']

# %%
### to group the texts according to their datings:

GNT_50 = " ".join(GNT_reduced[GNT_reduced["book"].str.startswith(('1Thess', 'Phlm', 'Rom', '1Cor', '2Cor', 'Gal'))]["lemma"].tolist())
GNT_60 = " ".join(GNT_reduced[GNT_reduced["book"].str.startswith(('Phil', 'Jas', 'Heb', 'Mark'))]["lemma"].tolist())
GNT_70 = " ".join(GNT_reduced[GNT_reduced["book"].str.startswith(('Matt'))]["lemma"].tolist())
GNT_80 = " ".join(GNT_reduced[GNT_reduced["book"].str.startswith(('Col', 'Luke', '2Thess', '2Pet'))]["lemma"].tolist())
GNT_90 = " ".join(GNT_reduced[GNT_reduced["book"].str.startswith(('Acts', 'Eph', 'Jude', 'Rev', 'John', '1Pet'))]["lemma"].tolist())
GNT_100 = " ".join(GNT_reduced[GNT_reduced["book"].str.startswith(('1John'))]["lemma"].tolist())
GNT_110 = " ".join(GNT_reduced[GNT_reduced["book"].str.startswith(('1Tim', '2Tim', '2John', '3John', 'Titus'))]["lemma"].tolist())

GNT_dated = [GNT_50, GNT_60, GNT_70, GNT_80, GNT_90, GNT_100, GNT_110]

# %%
### Replacement function to be used on our subsets

to_replace = {"πνεῦμα ἅγιος": "πνεῦμα_ἅγιον", "ἅγιος πνεῦμα": "πνεῦμα_ἅγιον"}
def replace_all(text, to_replace):
    for i, j in to_replace.items():
        text = text.replace(i, j)
    return text

# %%
## Generating subset data - the texts sorted by their dating

GNT_subsets_counts = []  ### a list to be filled by the data (sub-lists)
for GNT_subset in GNT_dated:
    GNT_subset = replace_all(GNT_subset, to_replace).split()
    ### add raw to the table with all the staff
    GNT_subsets_counts.append([len(GNT_subset), GNT_subset.count("πνεῦμα") + GNT_subset.count("πνεῦμα_ἅγιον"), ((GNT_subset.count("πνεῦμα") + GNT_subset.count("πνεῦμα_ἅγιον")) / float(len(GNT_subset))), GNT_subset.count("πνεῦμα_ἅγιον"), (GNT_subset.count("πνεῦμα_ἅγιον") / float(len(GNT_subset)))])
GNT_subsets_counts

GNT_subsets_counts_df = pd.DataFrame(GNT_subsets_counts, columns=["subset length", "FD πνεῦμα", "NormFD πνεῦμα", "FD πν_ἅγ", "NormFD πν_ἅγ"], index=["GNT_50", "GNT_60", "GNT_70", "GNT_80", "GNT_90", "GNT_100", "GNT_110"])
GNT_subsets_counts_df = GNT_subsets_counts_df.round(5)
GNT_subsets_counts_df
# Out:
#          subset length  FD πνεῦμα  NormFD πνεῦμα  FD πν_ἅγ  NormFD πν_ἅγ
# GNT_50           13662        115        0.00842        13       0.00095
# GNT_60           11856         42        0.00354         9       0.00076
# GNT_70           10826         19        0.00176         4       0.00037
# GNT_80           13664         42        0.00307        13       0.00095
# GNT_90           28858        142        0.00492        46       0.00159
# GNT_100           1198         12        0.01002         0       0.00000
# GNT_110           2665          7        0.00263         2       0.00075

# %%
## drawing the table

trace = go.Table(
    columnwidth = [180,180,180,180,180,180],
    header=dict(values=["subset", "subset length", "FD πνεῦμα", "NormFD πνεῦμα", "FD πν_ἅγ","NormFD πν_ἅγ"],
                fill = dict(color='#C2D4FF'),
                align = ['left'] * 3),
    cells=dict(values=[GNT_subsets_counts_df.index, GNT_subsets_counts_df["subset length"], GNT_subsets_counts_df["FD πνεῦμα"], GNT_subsets_counts_df["NormFD πνεῦμα"], GNT_subsets_counts_df["FD πν_ἅγ"], GNT_subsets_counts_df["NormFD πν_ἅγ"]],
               fill = dict(color='#F5F8FF'),
               align = ['left'] * 3))
layout = dict(width=550, height=650)
data = [trace]
fig = dict(data=data, layout=layout)
py.iplot(fig, filename = 'pandas_table')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kasev/40.embed" height="650px" width="550px"></iframe>

# %%
### drawing a graph
### two axes: https://plot.ly/python/multiple-axes/
### bar and scatter at the same time https://plot.ly/python/graphing-multiple-chart-types/


import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=GNT_subsets_counts_df.index,
    y=GNT_subsets_counts_df["subset length"],
    name= "Subset wordcount",
    marker=dict(
        color='rgb(204,204,204)',
    )
)
trace2 = go.Scatter(
    x=GNT_subsets_counts_df.index,
    y=GNT_subsets_counts_df["FD πνεῦμα"],
    name = "Frequency of the term πνεῦμα",
    yaxis="y2"
)
trace3 = go.Scatter(
    x=GNT_subsets_counts_df.index,
    y=GNT_subsets_counts_df["FD πν_ἅγ"],
    name = "Frequency of the term πνεῦμα_ἅγιον",
    yaxis="y2"
)

data = [trace1, trace2, trace3]
layout = go.Layout(
    title='Total usage per decade',
    yaxis=dict(
        title='subset length',
        range=[0, 30000]
    ),
    yaxis2=dict(
        title='term frequency',
        range=[0, 300],
        titlefont=dict(
            color='rgb(148, 103, 189)'
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        overlaying='y',
        side='right'
    ),
    legend=dict(
        x=0.2,
        y=1,
        traceorder='reversed',
        font=dict(
            family='sans-serif',
            size=12,
            color='#000'
        ),
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='bar-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kasev/42.embed" height="525px" width="100%"></iframe>

# %%
### drawing a graph
### two axes: https://plot.ly/python/multiple-axes/
### bar and scatter at the same time https://plot.ly/python/graphing-multiple-chart-types/


import plotly.plotly as py
import plotly.graph_objs as go


trace0 = go.Scatter(
    x=GNT_subsets_counts_df.index,
    y=GNT_subsets_counts_df["NormFD πνεῦμα"],
    name = "Normalized frequency of the term πνεῦμα"
)
trace1 = go.Scatter(
    x=GNT_subsets_counts_df.index,
    y=GNT_subsets_counts_df["NormFD πν_ἅγ"],
    name = "Normalized frequency of the term πνεῦμα_ἅγιον",

)

data = [trace0, trace1]
layout = go.Layout(
    title='Total usage per decade (normalized)',
    legend=dict(
        x=0.2,
        y=1,
        traceorder='reversed',
        font=dict(
            family='sans-serif',
            size=12,
            color='#000'
            ),
        )
    )


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='bar-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kasev/42.embed" height="525px" width="100%"></iframe>

# %%
### drawing a graph
### two axes: https://plot.ly/python/multiple-axes/
### bar and scatter at the same time https://plot.ly/python/graphing-multiple-chart-types/


import plotly.plotly as py
import plotly.graph_objs as go


trace0 = go.Scatter(
    x=GNT_subsets_counts_df.index,
    y=GNT_subsets_counts_df["NormFD πν_ἅγ"],
    name = "Normalized frequency of the term πνεῦμα"
)

data = [trace0]
layout = go.Layout(
    title='Total usage per decade (normalized)',
    legend=dict(
        x=0.2,
        y=1,
        traceorder='reversed',
        font=dict(
            family='sans-serif',
            size=12,
            color='#000'
            ),
        )
    )


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='bar-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kasev/42.embed" height="525px" width="100%"></iframe>

# %%
# Replacement function: a set of word pairs defined in the dictionary "to_replace"

to_replace = {"πνεῦμα ἅγιος": "πνεῦμα_ἅγιον", "ἅγιος πνεῦμα": "πνεῦμα_ἅγιον"}
def replace_all(text, to_replace):
    for i, j in to_replace.items():
        text = text.replace(i, j)
    return text

# New output data with the replaced terms
GNT_repl = replace_all(GNT_working, to_replace).split()

# %%
# Change the format: from str to nltk.text
 
GNT_repl = Text(GNT_repl)

# %%
# The normal concordance produces stdout only
# To put the output into a new variable we need a modified version of it 

def concordance(ci, word, width=80, lines=500):
    """
    Rewrite of nltk.text.ConcordanceIndex.print_concordance that returns results
    instead of printing them. 

    See:
    https://stackoverflow.com/questions/47649987/how-to-save-nltk-concordance-results-in-a-list
    
    """
    half_width = (width - len(word) - 2) // 2
    context = width // 4 # approx number of words of context

    results = []
    offsets = ci.offsets(word)
    if offsets:
        lines = min(lines, len(offsets))
        for i in offsets:
            if lines <= 0:
                break
            left = (' ' * half_width +
                    ' '.join(ci._tokens[i-context:i]))
            right = ' '.join(ci._tokens[i+1:i+context])
            left = left[-half_width:]
            right = right[:half_width]
            results.append('%s %s %s' % (left, ci._tokens[i], right))
            lines -= 1

    return results

# %%
### CONCORDANCE HOLY SPIRIT ("πνεῦμα ἅγιος and ἅγιος πνεῦμα)

from  nltk.text import ConcordanceIndex
ci = ConcordanceIndex(GNT_repl.tokens)
results = concordance(ci, 'πνεῦμα_ἅγιον')

concordance_holy_spirit = results

### The obtained concordance list is based on characters (150 characters window)
### As we are interested in th whole words only, we modify each line (i.e. concordance) into a list of terms
### and cut off the first and last words, which are often incomplete

conc_whole_words = []
for line in concordance_holy_spirit:
    conc_whole_words.append(" ".join(line.split()[1:-1]))
print(conc_whole_words)
# Out:
# ['εὑρίσκω ἐν γαστήρ ἔχω ἐκ πνεῦμα_ἅγιον ἰωσήφ ἀνήρ δίκαιος εἰμί μή θέλω', 'ὑπόδημα βαστάζω βαπτίζω ἐν πνεῦμα_ἅγιον πῦρ πτύον ἐν χείρ διακαθαρίζω', 'υἱός ἄνθρωπος ἀφίημι λέγω κατά πνεῦμα_ἅγιον οὐ ἀφίημι ἐν αἰών ἐν μέλλω', 'βαπτίζω εἰς ὄνομα πατήρ υἱός πνεῦμα_ἅγιον διδάσκω τηρέω πᾶς ἐντέλλομαι', 'ὑπόδημα βαπτίζω ὕδωρ βαπτίζω πνεῦμα_ἅγιον γίνομαι ἐν ἡμέρα ἔρχομαι ἰησοῦς', 'βλασφημέω βλασφημέω εἰς πνεῦμα_ἅγιον οὐ ἔ
ι εἰς σελεύκεια', 'πίστις σαῦλος παῦλος πίμπλημι πνεῦμα_ἅγιον ἀτενίζω εἰς λέγω πλήρης πᾶς', 'εἰς ἰκόνιον μαθητής πληρόω χαρά πνεῦμα_ἅγιον γίνομαι ἐν ἰκόνιον κατά', 'θεός μαρτυρέω δίδωμι πνεῦμα_ἅγιον καθώς οὐδείς διακρίνω μεταξύ', 'σιλᾶς διά λόγος ...

# %%
### good to know how many words remain in each line (excluding πνεῦμα_ἅγιον)

words_in_conc = []
for line in conc_whole_words:
    words_in_conc.append((len(line.split()) -1))
words_in_conc_df = pd.DataFrame(words_in_conc)

### desriptive stat is enough for us at this point
words_in_conc_df.describe()
# Out:
#                0
# count  87.000000
# mean    9.172414
# std     1.212406
# min     6.000000
# 25%     8.500000
# 50%     9.000000
# 75%    10.000000
# max    12.000000

# %%
### CONCORDANCE NORMAL SPIRIT
### Alternatively, we can work with all instances of pneuma: GNT_working = Text(GNT_working.split())

ci = ConcordanceIndex(GNT_repl.tokens)
results = concordance(ci, 'πνεῦμα')

concordance_pneuma = results

### The obtained concordance list is based on characters (150 characters window)
### As we are interested in th whole words only, we modify each line (i.e. concordance) into a list of terms
### and cut off the first and last words, which are often incomplete

conc_pneuma_whole_words = []
for line in concordance_pneuma:
    conc_pneuma_whole_words.append(" ".join(line.split()[1:-1]))
print(conc_pneuma_whole_words)
# Out:
# ['μαρία γυνή ἐν γεννάω ἐκ πνεῦμα εἰμί ἅγιος τίκτω υἱός καλέω ὄνομα', 'ἀπό ὕδωρ ὁράω ἀνοίγω οὐρανός ὁράω πνεῦμα θεός καταβαίνω ὡσεί περιστερά', 'τότε ἰησοῦς ἀνάγω εἰς ἔρημος ὑπό πνεῦμα πειράζω ὑπό διάβολος νηστεύω ἡμέρα', 'στόμα διδάσκω λέγω μακάριος πτωχός πνεῦμα εἰμί βασιλεία οὐρανός μακάριος', 'δαιμονίζομαι πολύς ἐκβάλλω πνεῦμα λόγος πᾶς κακῶς ἔχω θεραπεύω ὅπως', 'δώδεκα μαθητής δίδωμι ἐξουσία πνεῦμα ἀκάθαρτος ἐκβάλλω θεραπεύω πᾶς', 'δίδωμι ἐν ὥρα λαλέω οὐ εἰμί λαλέω πνεῦμα πατήρ λαλέω ἐν παραδίδωμι ἀδελφός', 'ἀγαπητός εὐδοκέω ψυχή τίθημι πνεῦμα ἐπί κρίσις ἔθνος ἀπαγγέλλω οὐ', 'υἱός ἐν ἐκβάλλω διά κριτής εἰμί ἐν πνεῦμα θεός ἐκβάλλω δαιμόνιον φθάνω ἐπί', 'ἁμαρτία βλασφημία ἀφίημι ἄνθρωπος πνεῦμα βλασφημία οὐ ἀφίημι λέγω λόγος', 'ὁράω πολύς σολομών ὧδε ἀκάθαρτος πνεῦμα ἐξέρχομαι ἀπό ἄνθρωπος διέρχομαι', 'παραλαμβάνω μετά ἑπτά ἕτερος πνεῦμα πονηρός εἰσέρχομαι κατοικέω ἐκεῖ', 'εἰμί λέγω δαυίδ λέγω πῶς δαυίδ ἐν πνε
conc_holy_spirit_list = list(filter(lambda x: x!= "πνεῦμα_ἅγιον", conc_holy_spirit_list))


conc_normal_spirit_list = [word for line in conc_pneuma_whole_words for word in line.split()]
# At the same time, we can remove πνεῦμα_ἅγιον from our lists
conc_normal_spirit_list = list(filter(lambda x: x!= "πνεῦμα", conc_normal_spirit_list))

# %%
### Normalized frequency distribution of the holy spirit concordance data (i.e. normalized BAG OF WORDS)
conc_holy_spirit_fd = nltk.FreqDist([word for word in conc_holy_spirit_list])
for word in conc_holy_spirit_fd:
    conc_holy_spirit_fd[word] /= float(len(conc_holy_spirit_list))

### Normalized frequency distribution of the normal spirit concordance data
conc_spirit_fd = nltk.FreqDist([word for word in conc_normal_spirit_list])
for word in conc_spirit_fd:
    conc_spirit_fd[word] /= float(len(conc_normal_spirit_list))
    
    
### Normalized freqeuncy distribution of respective the GNT data
GNT_working_norm_fd = nltk.FreqDist([word for word in GNT_working.split()])
GNT_working_len = len(GNT_working.split())
for word in GNT_working_norm_fd:
    GNT_working_norm_fd[word] /= float(GNT_working_len)

    
conc_holy_spirit_df = pd.DataFrame(conc_holy_spirit_fd.most_common(20), columns=["lemma", "conc_HS"])
conc_spirit_df = pd.DataFrame(conc_spirit_fd.most_common(1000), columns=["lemma", "conc_spirit"])
GNT_fd_df = pd.DataFrame(GNT_working_norm_fd.most_common(1000), columns=["lemma", "GNT"])

fd_pd_combined = pd.merge(conc_holy_spirit_df, conc_spirit_df, how="left", on="lemma")
fd_pd_combined = pd.merge(fd_pd_combined, GNT_fd_df, how="left", on="lemma")


### if you wish a better graph change to "ascending=True" 
fd_pd_combined = fd_pd_combined.sort_values(by=["conc_HS"], ascending=True)
fd_pd_combined = fd_pd_combined.round(5)
fd_pd_combined
# Out:
#        lemma  conc_HS  conc_spirit      GNT
# 19    δίδωμι  0.00877      0.01009  0.00500
# 17   δύναμις  0.01003      0.00348  0.00144
# 16  πίμπλημι  0.01003          NaN  0.00029
# 15     πατήρ  0.01003      0.00626  0.00497
# 14      χείρ  0.01003      0.00139  0.00213
# 13        μή  0.01003      0.01496  0.01280
# 18       ἀπό  0.01003      0.00870  0.00781
# 12    κύριος  0.01128      0.01218  0.00867
# 11       διά  0.01253      0.01079  0.00805
# 10   λαμβάνω  0.01253      0.00557  0.00312
# 9        πᾶς  0.01253      0.01322  0.01500
# 8    βαπτίζω  0.01253      0.00209  0.00092
# 7      λαλέω  0.01504      0.00522  0.00360
# 6         οὐ  0.01504      0.02296  0.01959
# 5        ἐπί  0.01880      0.00835  0.01070
# 4       θεός  0.02130      0.02749  0.01583
# 3        εἰς  0.02130      0.01740  0.02132
# 2       εἰμί  0.02757      0.03688  0.02967
# 1       λέγω  0.03008      0.02227  0.02723
# 0         ἐν  0.06892      0.05880  0.03312

# %%
## just to look at the most common 50 in HS concordance

pd.DataFrame(conc_spirit_fd.most_common(50), columns=["lemma", "conc_spirit"])
# Out:
#         lemma  conc_spirit
# 0          ἐν     0.058803
# 1        εἰμί     0.036882
# 2        θεός     0.027488
# 3          οὐ     0.022965
# 4        λέγω     0.022269
# 5         εἰς     0.017397
# 6          ἐκ     0.016701
# 7        σάρξ     0.015658
# 8          μή     0.014962
# 9      ἰησοῦς     0.014614
# 10        πᾶς     0.013222
# 11     κύριος     0.012178
# 12        διά     0.010786
# 13       κατά     0.010786
# 14    χριστός     0.010438
# 15     δίδωμι     0.010090
# 16        ἔχω     0.009743
# 17        ἀπό     0.008699
# 18  ἀκάθαρτος     0.008699
# 19       ὁράω     0.008351
# 20        ἐπί     0.008351
# 21        εἷς     0.008003
# 22   ἄνθρωπος     0.007307
# 23      ἀκούω     0.006611
# 24      πατήρ     0.006263
# 25       υἱός     0.005567
# 26    λαμβάνω     0.005567
# 27      λαλέω     0.005219
# 28       πρός     0.005219
# 29    ἀλήθεια     0.004871
# 30      ἡμέρα     0.004523
# 31       μετά     0.004523
# 32         ὡς     0.004523
# 33       οὕτω     0.004523
# 34       οἶδα     0.004523
# 35       σῶμα     0.004523
# 36       ἑπτά     0.004175
# 37        ζάω     0.004175
# 38     πίστις     0.004175
# 39       ὕδωρ     0.003827
# 40    ἔρχομαι     0.003827
# 41      ἄλλος     0.003827
# 42      ὄνομα     0.003479
# 43      πολύς     0.003479
# 44  ἐξέρχομαι     0.003479
# 45    δύναμις     0.003479
# 46        ζωή     0.003479
# 47     κόσμος     0.003479
# 48    γινώσκω     0.003479
# 49    ἄγγελος     0.003479

# %%
### GRAPH
### generated by means of Plotly

data = [
     go.Bar(
        y=fd_pd_combined["lemma"],
        x=fd_pd_combined["GNT"],
        name= "NormFD of the term in the GNT text",
        orientation = 'h'
        ),   
    go.Bar(
       y=fd_pd_combined["lemma"],
        x=fd_pd_combined["conc_spirit"],
        name= "NormFD of the term in πνεῦμα conc.",
        orientation = 'h'
        ),
    go.Bar(
        y=fd_pd_combined["lemma"],
        x=fd_pd_combined["conc_HS"],
        name= "NormFD of the term in πνεῦμα_ἅγιον conc.",
        orientation = 'h',
        ),
    ]

layout = go.Layout(
    barmode='group',
    title='Holy Spirit Concorandce Distributions',
    autosize=False,
    width=700,
    height=700,
    legend=dict(
        x=0.4,
        y=0.05,
        traceorder='reversed',
        font=dict(
            family='sans-serif',
            size=12,
            color='#000'
        ),
        ## bgcolor='#E2E2E2',
        ## bordercolor='#FFFFFF',
        ## borderwidth=2
    )
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='holy_spirit')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kasev/38.embed" height="700px" width="700px"></iframe>

# %%
## drawing table of the same

trace = go.Table(
    columnwidth = [100,180,180,180],
    header=dict(values=["lemma", "normFD πν_ἅγ", "normFD πνεῦμα", "normFD GNT"], ###fd_pd_combined.columns],
                fill = dict(color='#C2D4FF'),
                align = ['left'] * 3),
    cells=dict(values=[fd_pd_combined.lemma, fd_pd_combined.conc_HS, fd_pd_combined.conc_spirit, fd_pd_combined.GNT],
               fill = dict(color='#F5F8FF'),
               align = ['left'] * 3))
layout = dict(width=550, height=650)
data = [trace]
fig = dict(data=data, layout=layout)
py.iplot(fig, filename = 'pandas_table')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kasev/40.embed" height="650px" width="550px"></iframe>
